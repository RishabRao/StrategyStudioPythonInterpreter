# %% [markdown]
# # Fill in the MyStrategy Class below to specify your strategy logic

# %%
from strategy import *
from BaseStrategy import BaseStrategy

class MyStrategy(BaseStrategy):
    def __init__(self, strategy_actions):
        self.small_window = 40
        self.big_window = 100
        self.small_sum = 0.0
        self.big_sum = 0.0
        self.stock_size = 0
        self.revenue = 0.0
        self.capital = 0.0
        self.trade_times = 0
        self.inc = 0
        self.small_set = []
        self.big_set = []

        super().__init__(strategy_actions)

    def OnResetStrategyState(self):
        pass
        
    # Set flags before the strategy is started
    def SetFlags(self):
        pass

    def OnTrade(self, msg):

        instrument = msg.instrument(); 
        mid_price = (instrument.top_quote().ask() + instrument.top_quote().bid()) / 2

        self.small_sum += mid_price
        self.big_sum += mid_price

        self.small_set.append(mid_price)
        self.big_set.append(mid_price)

        if len(self.small_set) > self.small_window: 
            self.small_sum -= self.small_set.pop()
       
        if len(self.big_set) > self.big_window: 
            self.big_sum -= self.big_set.pop()

        small_average = self.small_sum / len(self.small_set)
        big_average = self.big_sum / len(self.big_set)

        if small_average > big_average:
            self.SendOrder(instrument, 100)    
            self.stock_size += 100
            self.revenue -= instrument.top_quote().ask() * 100
            self.trade_times += 1 

        elif small_average < big_average and self.stock_size > 0:
            self.SendOrder(instrument, -100)    
            self.stock_size -= 100
            self.revenue += instrument.top_quote().bid() * 100
            self.trade_times += 1 
        
        self.capital = self.stock_size * instrument.top_quote().bid() + self.revenue

        print("Capital = " + str(self.capital) + " size = " + str(self.stock_size) + " trade times = " + str(self.trade_times))
        
        pass


    def OnTopQuote(self, msg):
        pass
       
    def OnQuote(self, msg): 
        pass
    
    def OnBar(self, msg): 
        pass

    def OnDepth(self, msg):
        pass
    
    def OnResetStrategyState(self): 
        pass

    def OnOrderUpdate(self, msg): 
        pass
    
    def OnResetStrategyState(self): 
        pass

    def RegisterForStrategyEvents(self, eventRegister, currDate):
        print("RegisterForStrategyEvents()")    
        print(currDate)
        pass
    
    def SendOrder(self, instrument, trade_size): 
        price = 0
        action = ""

        if trade_size > 0: # buy 
            price = instrument.top_quote().ask()
            action = "buy"
        else: # sell
            price = instrument.top_quote().bid()
            action = "sell"
        
        params = OrderParams(instrument, abs(trade_size), price, MARKET_CENTER_ID_IEX, (ORDER_SIDE_BUY if trade_size > 0 else ORDER_SIDE_SELL), ORDER_TIF_DAY, ORDER_TYPE_LIMIT)

        print("SendTradeOrder(): about to send new order for size " + str(trade_size) + " at $" + str(price) + " to " + str(action) + " " + instrument.symbol())
        
        self.trade_actions().SendNewOrder(params)
        pass

    def OnNews(self, msg):
        pass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from strategy import *
#       2 from BaseStrategy import BaseStrategy
#       4 class MyStrategy(BaseStrategy):
#
# ModuleNotFoundError: No module named 'strategy'

# %% [markdown]
# # Run the cell below to export your strategy and run a backtest

# %%
# Run Script
# !./runstrat.sh
# Out:
# /usr/local/lib/python3.10/site-packages/traitlets/traitlets.py:2930: FutureWarning: --TagRemovePreprocessor.remove_cell_tags={"remove"} for containers is deprecated in traitlets 5.0. You can pass `--TagRemovePreprocessor.remove_cell_tags item` ... multiple times to add items to a list.
#   warn(
# [NbConvertApp] Converting notebook your_strategy.ipynb to python
# [NbConvertApp] Writing 3340 bytes to ../MyStrategy.py
# Great! You properly cloned the repo using --recursive!
# You already have your ssh key! great!
# Great! You already downloaded the Strategy Studio SDK
# Great! You already downloaded the Strategy Studio Backtesting Engine!
# Great! You already placed your license.txt file in this folder!
# Compressing PybindStrategy
# All dependencies are met! Launching VM!!
# Bringing up VM
# declare -x VAGRANT_CHECKPOINT_DISABLE="1"
# declare -x VAGRANT_HOME="/Users/satyanshy/Documents/IE421/group_02_project/strategystudioubuntu2004/vagrant_home"
# Bringing machine 'default' up with 'virtualbox' provider...
# ==> default: Machine already provisioned. Run `vagrant provision` or use the `--provision`
# ==> default: flag to force provisioning. Provisioners marked to run always will still run.
# Great! You've already generated the required market data!
# Great! You've generated the required market data!
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.metadata:_kMDItemUserTags'
# removing old .so files...
# cp PybindStrategy.so /home/vagrant/ss/bt/strategies_dlls/.
# cp MyStrategy.py BaseStrategy.py /home/vagrant/ss/bt/strategies_dlls/.
# cp MyStrategy.py BaseStrategy.py /home/vagrant/ss/bt/.
# Initializing Strategy Studio Backtesting Server...
# Initializing Strategy Server...
# PROCESSOR_LOG_LEVEL configured as DEBUG
# Strategy Studio Server v 3.4.0.0
# Protocol Version v21.0
# Recovery mode disabled.
# Loading corporate action adapter dll /home/vagrant/ss/bt/./corporate_action_adapters/TextCorporateActionAdapter.so...
# Loading instrument information from reference database...
# Loading equity instruments...
# Finished loading 0 equity instruments from reference database.
# Loading futures instruments...
# Finished loading 0 futures instruments from reference database.
# Loading options instruments...
# Finished loading 0 option instruments from reference database.
# Loading spot currency pair instruments...
# Finished loading 0 spot currency pairs from reference database.
# Loading bond instruments...
# Finished loading 0 bond instruments from reference database.
# Finished loading instrument information from reference database.
# Starting Seq Num = 1
# Loading strategy dll /home/vagrant/ss/bt/strategies_dlls/PybindStrategy.so...
# Found new strategy type info for strategy PybindStrategy
# Loaded strategy type PybindStrategy from strategy DLL.
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/NomuraTickReader.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/OneTickAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/TextTickReader.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/LMAXAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/TickDataDotComAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/NanexAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/MorningstarTickAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/KDBAdapter.so...
# Application state changed to STATE_APP_INITIALIZED
# Strategy Server initialized...
# Starting Strategy Studio Backtesting Server...
# Starting Strategy Server...
# Application state changed to STATE_APP_STARTING
# Application state changed to STATE_MARKET_OPENING
# Application state changed to STATE_RUNNING
# Acceptor thread started.Strategy Server started...
# Running Strategy Studio Backtesting Server...
# Command line disabled. Type CTRL-C to end.
#
# Login received from connection id 0
# Strategy TestPybindStrategy added to processor 0.
#
# Quitting.
# Connection id 0 finished.
# Connection id 1 finished.
# Login received from connection id 1
#
# --Strategy Instance List--
# TestPybindStrategy
# ----------------------------
#
#
# Quitting.
# Connection id 1 finished.
# Connection id 1 finished.
# Login received from connection id 2
# Stopping Strategy Studio Backtesting Server...
# Stopping Strategy Server...
# Application state changed to STATE_APP_STOPPING
#
# Quitting.
# Connection id 1 finished.
# Connection id 2 finished.
# Caught a signal: 1. Alerting Strategy Studio...
# Sleeping for 2 seconds while waiting for strategy studio to boot
# Initializing Strategy Studio Backtesting Server...
# Initializing Strategy Server...
# PROCESSOR_LOG_LEVEL configured as DEBUG
# Strategy Studio Server v 3.4.0.0
# Protocol Version v21.0
# Recovery mode disabled.
# Loading corporate action adapter dll /home/vagrant/ss/bt/./corporate_action_adapters/TextCorporateActionAdapter.so...
# Loading instrument information from reference database...
# Loading equity instruments...
# Finished loading 0 equity instruments from reference database.
# Loading futures instruments...
# Finished loading 0 futures instruments from reference database.
# Loading options instruments...
# Finished loading 0 option instruments from reference database.
# Loading spot currency pair instruments...
# Finished loading 0 spot currency pairs from reference database.
# Loading bond instruments...
# Finished loading 0 bond instruments from reference database.
# Finished loading instrument information from reference database.
# Starting Seq Num = 1
# Loading strategy dll /home/vagrant/ss/bt/strategies_dlls/PybindStrategy.so...
# Found new strategy type info for strategy PybindStrategy
# Loaded strategy type PybindStrategy from strategy DLL.
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/NomuraTickReader.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/OneTickAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/TextTickReader.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/LMAXAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/TickDataDotComAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/NanexAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/MorningstarTickAdapter.so...
# Loading backtest reader library /home/vagrant/ss/bt/./backtester-readers/KDBAdapter.so...
# Application state changed to STATE_APP_INITIALIZED
# Strategy Server initialized...
# Starting Strategy Studio Backtesting Server...
# Starting Strategy Server...
# Application state changed to STATE_APP_STARTING
# Application state changed to STATE_MARKET_OPENING
# Acceptor thread started.
# Application state changed to STATE_RUNNING
# Strategy Server started...
# Running Strategy Studio Backtesting Server...
# Command line disabled. Type CTRL-C to end.
# Login received from connection id 0
# Starting backtest experiment 1 running 1 strategy with start date 2021-Nov-05 and end date 2021-Nov-05
# DataSourceMgr::BuildDataSource: Received request to build data source BacktesterReader for processor id 1
# Started backtest experiment 1 with start date 2021-Nov-05 and end date 2021-Nov-05
#
# Quitting.
# Connection id 0 finished.
# Connection id 1 finished.
# Last line found:,12432
# Sleeping for 10 seconds...
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# Capital = 0.0 size = 0 trade times = 0
# SendTradeOrder(): about to send new order for size 100 at $151.87 to buy AAPL
# Capital = -421.0 size = 100 trade times = 1
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -189.0 size = 200 trade times = 2
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -198.0 size = 300 trade times = 3
# SendTradeOrder(): about to send new order for size -100 at $151.87 to sell AAPL
# Capital = -198.0 size = 200 trade times = 4
# SendTradeOrder(): about to send new order for size -100 at $151.87 to sell AAPL
# Capital = -198.0 size = 100 trade times = 5
# SendTradeOrder(): about to send new order for size -100 at $151.87 to sell AAPL
# Capital = -198.0 size = 0 trade times = 6
# Capital = -198.0 size = 0 trade times = 6
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -616.0 size = 100 trade times = 7
# SendTradeOrder(): about to send new order for size 100 at $151.83 to buy AAPL
# Capital = -1033.0 size = 200 trade times = 8
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -397.9999999999927 size = 300 trade times = 9
# SendTradeOrder(): about to send new order for size 100 at $151.85 to buy AAPL
# Capital = -2068.0 size = 400 trade times = 10
# SendTradeOrder(): about to send new order for size 100 at $151.85 to buy AAPL
# Capital = -2487.0 size = 500 trade times = 11
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -3103.0 size = 600 trade times = 12
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -3719.0 size = 700 trade times = 13
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -4335.0 size = 800 trade times = 14
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -1198.0 size = 900 trade times = 15
# SendTradeOrder(): about to send new order for size 100 at $151.89 to buy AAPL
# Capital = -1204.0 size = 1000 trade times = 16
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -1414.0 size = 1100 trade times = 17
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -6606.0 size = 1200 trade times = 18
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -1629.0 size = 1300 trade times = 19
# SendTradeOrder(): about to send new order for size 100 at $153.82 to buy AAPL
# Capital = -7640.0 size = 1400 trade times = 20
# SendTradeOrder(): about to send new order for size 100 at $151.89 to buy AAPL
# Capital = -1778.0 size = 1500 trade times = 21
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -7725.0 size = 1600 trade times = 22
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -1961.999999999971 size = 1700 trade times = 23
# SendTradeOrder(): about to send new order for size 100 at $151.85 to buy AAPL
# Capital = -2054.0 size = 1800 trade times = 24
# SendTradeOrder(): about to send new order for size 100 at $151.85 to buy AAPL
# Capital = -2061.0 size = 1900 trade times = 25
# SendTradeOrder(): about to send new order for size 100 at $151.83 to buy AAPL
# Capital = -9266.0 size = 2000 trade times = 26
# SendTradeOrder(): about to send new order for size 100 at $151.81 to buy AAPL
# Capital = -9629.0 size = 2100 trade times = 27
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -1947.0 size = 2200 trade times = 28
# SendTradeOrder(): about to send new order for size 100 at $151.94 to buy AAPL
# Capital = -10375.0 size = 2300 trade times = 29
# SendTradeOrder(): about to send new order for size 100 at $151.94 to buy AAPL
# Capital = -1871.0 size = 2400 trade times = 30
# SendTradeOrder(): about to send new order for size 100 at $151.94 to buy AAPL
# Capital = -1877.0 size = 2500 trade times = 31
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -1897.0 size = 2600 trade times = 32
# SendTradeOrder(): about to send new order for size 100 at $151.95 to buy AAPL
# Capital = -1956.0 size = 2700 trade times = 33
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -12388.0 size = 2800 trade times = 34
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -1955.0 size = 2900 trade times = 35
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2082.0 size = 3000 trade times = 36
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2151.0 size = 3100 trade times = 37
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2252.0 size = 3200 trade times = 38
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2289.0 size = 3300 trade times = 39
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2358.0 size = 3400 trade times = 40
# SendTradeOrder(): about to send new order for size 100 at $151.97 to buy AAPL
# Capital = -2329.0 size = 3500 trade times = 41
# SendTradeOrder(): about to send new order for size 100 at $151.97 to buy AAPL
# Capital = -2334.0 size = 3600 trade times = 42
# SendTradeOrder(): about to send new order for size 100 at $151.97 to buy AAPL
# Capital = -2339.0 size = 3700 trade times = 43
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2483.0 size = 3800 trade times = 44
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2553.0 size = 3900 trade times = 45
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2623.0 size = 4000 trade times = 46
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -20077.0 size = 4100 trade times = 47
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -20571.0 size = 4200 trade times = 48
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -3392.0 size = 4300 trade times = 49
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -21559.0 size = 4400 trade times = 50
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -22053.0 size = 4500 trade times = 51
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -22547.0 size = 4600 trade times = 52
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -4100.0 size = 4700 trade times = 53
# SendTradeOrder(): about to send new order for size 100 at $151.75 to buy AAPL
# Capital = -4106.0 size = 4800 trade times = 54
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -4393.0 size = 4900 trade times = 55
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -4488.0 size = 5000 trade times = 56
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -4736.0 size = 5100 trade times = 57
# SendTradeOrder(): about to send new order for size 100 at $151.71 to buy AAPL
# Capital = -4537.0 size = 5200 trade times = 58
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -25740.0 size = 5300 trade times = 59
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -4364.0 size = 5400 trade times = 60
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -4453.0 size = 5500 trade times = 61
# SendTradeOrder(): about to send new order for size 100 at $151.65 to buy AAPL
# Capital = -4951.0 size = 5600 trade times = 62
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -27529.0 size = 5700 trade times = 63
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -4447.0 size = 5800 trade times = 64
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -28345.0 size = 5900 trade times = 65
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -28753.0 size = 6000 trade times = 66
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -29161.0 size = 6100 trade times = 67
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -29569.0 size = 6200 trade times = 68
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -29977.0 size = 6300 trade times = 69
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -5296.999999999884 size = 6400 trade times = 70
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -30793.0 size = 6500 trade times = 71
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -5395.0 size = 6600 trade times = 72
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -31609.0 size = 6700 trade times = 73
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -32017.0 size = 6800 trade times = 74
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -32425.0 size = 6900 trade times = 75
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -5113.0 size = 7000 trade times = 76
# SendTradeOrder(): about to send new order for size 100 at $151.63 to buy AAPL
# Capital = -33230.0 size = 7100 trade times = 77
# SendTradeOrder(): about to send new order for size 100 at $151.62 to buy AAPL
# Capital = -33626.0 size = 7200 trade times = 78
# SendTradeOrder(): about to send new order for size 100 at $151.63 to buy AAPL
# Capital = -34023.0 size = 7300 trade times = 79
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = -34417.0 size = 7400 trade times = 80
# SendTradeOrder(): about to send new order for size 100 at $151.57 to buy AAPL
# Capital = -34808.0 size = 7500 trade times = 81
# SendTradeOrder(): about to send new order for size 100 at $151.57 to buy AAPL
# Capital = -35199.0 size = 7600 trade times = 82
# SendTradeOrder(): about to send new order for size 100 at $151.59 to buy AAPL
# Capital = -5639.0 size = 7700 trade times = 83
# SendTradeOrder(): about to send new order for size 100 at $151.59 to buy AAPL
# Capital = -35985.0 size = 7800 trade times = 84
# SendTradeOrder(): about to send new order for size 100 at $151.56 to buy AAPL
# Capital = -36375.0 size = 7900 trade times = 85
# SendTradeOrder(): about to send new order for size 100 at $151.61 to buy AAPL
# Capital = -5570.0 size = 8000 trade times = 86
# SendTradeOrder(): about to send new order for size 100 at $151.61 to buy AAPL
# Capital = -5332.0 size = 8100 trade times = 87
# SendTradeOrder(): about to send new order for size 100 at $151.61 to buy AAPL
# Capital = -5334.0 size = 8200 trade times = 88
# SendTradeOrder(): about to send new order for size 100 at $151.61 to buy AAPL
# Capital = -37955.0 size = 8300 trade times = 89
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -5351.0 size = 8400 trade times = 90
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -38771.0 size = 8500 trade times = 91
# SendTradeOrder(): about to send new order for size 100 at $151.55 to buy AAPL
# Capital = -39160.0 size = 8600 trade times = 92
# SendTradeOrder(): about to send new order for size 100 at $151.55 to buy AAPL
# Capital = -39549.0 size = 8700 trade times = 93
# SendTradeOrder(): about to send new order for size 100 at $151.55 to buy AAPL
# Capital = -39938.0 size = 8800 trade times = 94
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -40346.0 size = 8900 trade times = 95
# SendTradeOrder(): about to send new order for size 100 at $151.62 to buy AAPL
# Capital = -5642.0 size = 9000 trade times = 96
# SendTradeOrder(): about to send new order for size 100 at $151.64 to buy AAPL
# Capital = -5194.999999999767 size = 9100 trade times = 97
# SendTradeOrder(): about to send new order for size 100 at $151.64 to buy AAPL
# Capital = -5197.999999999767 size = 9200 trade times = 98
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = -5569.0 size = 9300 trade times = 99
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = -5666.0 size = 9400 trade times = 100
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -4635.000000000233 size = 9500 trade times = 101
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -4354.0 size = 9600 trade times = 102
# SendTradeOrder(): about to send new order for size 100 at $151.77 to buy AAPL
# Capital = -3973.0 size = 9700 trade times = 103
# SendTradeOrder(): about to send new order for size 100 at $151.82 to buy AAPL
# Capital = -3981.0 size = 9800 trade times = 104
# SendTradeOrder(): about to send new order for size 100 at $151.79 to buy AAPL
# Capital = -3788.0 size = 9900 trade times = 105
# SendTradeOrder(): about to send new order for size 100 at $151.76 to buy AAPL
# Capital = -4388.0 size = 10000 trade times = 106
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -3594.0 size = 10100 trade times = 107
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -3600.0 size = 10200 trade times = 108
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -3194.0 size = 10300 trade times = 109
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -2994.0 size = 10400 trade times = 110
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = -2020.0 size = 10500 trade times = 111
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -2864.999999999767 size = 10600 trade times = 112
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -3083.0 size = 10700 trade times = 113
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -3089.0 size = 10800 trade times = 114
# SendTradeOrder(): about to send new order for size 100 at $151.92 to buy AAPL
# Capital = -2661.0 size = 10900 trade times = 115
# SendTradeOrder(): about to send new order for size 100 at $151.94 to buy AAPL
# Capital = -2667.0 size = 11000 trade times = 116
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3111.0 size = 11100 trade times = 117
# SendTradeOrder(): about to send new order for size 100 at $151.96 to buy AAPL
# Capital = -2227.000000000233 size = 11200 trade times = 118
# SendTradeOrder(): about to send new order for size 100 at $151.95 to buy AAPL
# Capital = -2230.000000000233 size = 11300 trade times = 119
# SendTradeOrder(): about to send new order for size 100 at $151.98 to buy AAPL
# Capital = -2008.0 size = 11400 trade times = 120
# SendTradeOrder(): about to send new order for size 100 at $152.03 to buy AAPL
# Capital = -1327.0 size = 11500 trade times = 121
# SendTradeOrder(): about to send new order for size 100 at $152.1 to buy AAPL
# Capital = -641.0 size = 11600 trade times = 122
# SendTradeOrder(): about to send new order for size 100 at $152.1 to buy AAPL
# Capital = -410.99999999976717 size = 11700 trade times = 123
# SendTradeOrder(): about to send new order for size 100 at $152.1 to buy AAPL
# Capital = -412.99999999976717 size = 11800 trade times = 124
# SendTradeOrder(): about to send new order for size 100 at $152.09 to buy AAPL
# Capital = -652.0 size = 11900 trade times = 125
# SendTradeOrder(): about to send new order for size 100 at $152.1 to buy AAPL
# Capital = -536.0 size = 12000 trade times = 126
# SendTradeOrder(): about to send new order for size 100 at $152.12 to buy AAPL
# Capital = -299.0 size = 12100 trade times = 127
# SendTradeOrder(): about to send new order for size 100 at $152.12 to buy AAPL
# Capital = -180.0 size = 12200 trade times = 128
# SendTradeOrder(): about to send new order for size 100 at $152.12 to buy AAPL
# Capital = -427.99999999976717 size = 12300 trade times = 129
# SendTradeOrder(): about to send new order for size 100 at $152.12 to buy AAPL
# Capital = -431.99999999976717 size = 12400 trade times = 130
# SendTradeOrder(): about to send new order for size 100 at $152.1 to buy AAPL
# Capital = -433.99999999976717 size = 12500 trade times = 131
# SendTradeOrder(): about to send new order for size 100 at $152.17 to buy AAPL
# Capital = 565.0 size = 12600 trade times = 132
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 308.99999999976717 size = 12700 trade times = 133
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 304.99999999976717 size = 12800 trade times = 134
# SendTradeOrder(): about to send new order for size 100 at $152.16 to buy AAPL
# Capital = 302.99999999976717 size = 12900 trade times = 135
# SendTradeOrder(): about to send new order for size 100 at $152.19 to buy AAPL
# Capital = 687.9999999997672 size = 13000 trade times = 136
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 556.0 size = 13100 trade times = 137
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 554.0 size = 13200 trade times = 138
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 552.0 size = 13300 trade times = 139
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 14.0 size = 13400 trade times = 140
# SendTradeOrder(): about to send new order for size 100 at $152.18 to buy AAPL
# Capital = 8.0 size = 13500 trade times = 141
# SendTradeOrder(): about to send new order for size 100 at $152.17 to buy AAPL
# Capital = 274.99999999976717 size = 13600 trade times = 142
# SendTradeOrder(): about to send new order for size 100 at $152.14 to buy AAPL
# Capital = -273.0 size = 13700 trade times = 143
# SendTradeOrder(): about to send new order for size 100 at $152.1 to buy AAPL
# Capital = -549.0 size = 13800 trade times = 144
# SendTradeOrder(): about to send new order for size 100 at $152.06 to buy AAPL
# Capital = -1381.0 size = 13900 trade times = 145
# SendTradeOrder(): about to send new order for size 100 at $152.06 to buy AAPL
# Capital = -1385.0 size = 14000 trade times = 146
# SendTradeOrder(): about to send new order for size 100 at $152.02 to buy AAPL
# Capital = -1667.0 size = 14100 trade times = 147
# SendTradeOrder(): about to send new order for size 100 at $151.99 to buy AAPL
# Capital = -2234.0 size = 14200 trade times = 148
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -3659.0 size = 14300 trade times = 149
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -3664.0 size = 14400 trade times = 150
# SendTradeOrder(): about to send new order for size 100 at $151.92 to buy AAPL
# Capital = -3235.0 size = 14500 trade times = 151
# SendTradeOrder(): about to send new order for size 100 at $151.95 to buy AAPL
# Capital = -2803.0 size = 14600 trade times = 152
# SendTradeOrder(): about to send new order for size 100 at $151.95 to buy AAPL
# Capital = -2512.0 size = 14700 trade times = 153
# SendTradeOrder(): about to send new order for size 100 at $151.98 to buy AAPL
# Capital = -2516.0 size = 14800 trade times = 154
# SendTradeOrder(): about to send new order for size 100 at $152.04 to buy AAPL
# Capital = -1632.0 size = 14900 trade times = 155
# SendTradeOrder(): about to send new order for size 100 at $152.04 to buy AAPL
# Capital = -1636.0 size = 15000 trade times = 156
# SendTradeOrder(): about to send new order for size 100 at $151.97 to buy AAPL
# Capital = -67167.0 size = 15100 trade times = 157
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -67591.0 size = 15200 trade times = 158
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3906.0 size = 15300 trade times = 159
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -3757.0 size = 15400 trade times = 160
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -3761.0 size = 15500 trade times = 161
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -4075.0 size = 15600 trade times = 162
# SendTradeOrder(): about to send new order for size 100 at $151.87 to buy AAPL
# Capital = -4078.0 size = 15700 trade times = 163
# SendTradeOrder(): about to send new order for size 100 at $151.79 to buy AAPL
# Capital = -5179.0 size = 15800 trade times = 164
# SendTradeOrder(): about to send new order for size 100 at $151.79 to buy AAPL
# Capital = -5181.0 size = 15900 trade times = 165
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5184.0 size = 16000 trade times = 166
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5187.0 size = 16100 trade times = 167
# SendTradeOrder(): about to send new order for size 100 at $151.79 to buy AAPL
# Capital = -5189.0 size = 16200 trade times = 168
# SendTradeOrder(): about to send new order for size 100 at $151.73 to buy AAPL
# Capital = -6326.0 size = 16300 trade times = 169
# SendTradeOrder(): about to send new order for size 100 at $151.73 to buy AAPL
# Capital = -6329.0 size = 16400 trade times = 170
# SendTradeOrder(): about to send new order for size 100 at $151.73 to buy AAPL
# Capital = -6332.0 size = 16500 trade times = 171
# SendTradeOrder(): about to send new order for size 100 at $151.73 to buy AAPL
# Capital = -6335.0 size = 16600 trade times = 172
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7003.0 size = 16700 trade times = 173
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5337.0 size = 16800 trade times = 174
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5172.0 size = 16900 trade times = 175
# SendTradeOrder(): about to send new order for size 100 at $151.77 to buy AAPL
# Capital = -5852.0 size = 17000 trade times = 176
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -6024.0 size = 17100 trade times = 177
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7054.0 size = 17200 trade times = 178
# SendTradeOrder(): about to send new order for size 100 at $151.72 to buy AAPL
# Capital = -6541.0 size = 17300 trade times = 179
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -6372.0 size = 17400 trade times = 180
# SendTradeOrder(): about to send new order for size 100 at $151.66 to buy AAPL
# Capital = -7768.0 size = 17500 trade times = 181
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7072.0 size = 17600 trade times = 182
# SendTradeOrder(): about to send new order for size 100 at $151.67 to buy AAPL
# Capital = -7427.000000000466 size = 17700 trade times = 183
# SendTradeOrder(): about to send new order for size 100 at $151.67 to buy AAPL
# Capital = -7430.000000000466 size = 17800 trade times = 184
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7078.0 size = 17900 trade times = 185
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -7440.000000000466 size = 18000 trade times = 186
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -7083.0 size = 18100 trade times = 187
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -7086.0 size = 18200 trade times = 188
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -7454.000000000466 size = 18300 trade times = 189
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -7274.0 size = 18400 trade times = 190
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -7093.0 size = 18500 trade times = 191
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -6910.0 size = 18600 trade times = 192
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -6912.000000000466 size = 18700 trade times = 193
# SendTradeOrder(): about to send new order for size 100 at $151.71 to buy AAPL
# Capital = -6352.0 size = 18800 trade times = 194
# SendTradeOrder(): about to send new order for size 100 at $151.76 to buy AAPL
# Capital = -5602.0 size = 18900 trade times = 195
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5416.0 size = 19000 trade times = 196
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5419.0 size = 19100 trade times = 197
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5422.0 size = 19200 trade times = 198
# SendTradeOrder(): about to send new order for size 100 at $151.81 to buy AAPL
# Capital = -5235.0 size = 19300 trade times = 199
# SendTradeOrder(): about to send new order for size 100 at $151.86 to buy AAPL
# Capital = -3886.9999999995343 size = 19400 trade times = 200
# SendTradeOrder(): about to send new order for size 100 at $151.86 to buy AAPL
# Capital = -3889.9999999995343 size = 19500 trade times = 201
# SendTradeOrder(): about to send new order for size 100 at $151.86 to buy AAPL
# Capital = -4481.0 size = 19600 trade times = 202
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5464.0 size = 19700 trade times = 203
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5073.0 size = 19800 trade times = 204
# SendTradeOrder(): about to send new order for size 100 at $151.82 to buy AAPL
# Capital = -4481.0 size = 19900 trade times = 205
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -3291.9999999995343 size = 20000 trade times = 206
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -2694.0000000004657 size = 20100 trade times = 207
# SendTradeOrder(): about to send new order for size 100 at $151.92 to buy AAPL
# Capital = -2495.0 size = 20200 trade times = 208
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -2901.0 size = 20300 trade times = 209
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -2700.0000000004657 size = 20400 trade times = 210
# SendTradeOrder(): about to send new order for size 100 at $151.91 to buy AAPL
# Capital = -2702.0000000004657 size = 20500 trade times = 211
# SendTradeOrder(): about to send new order for size 100 at $151.87 to buy AAPL
# Capital = -3730.0 size = 20600 trade times = 212
# SendTradeOrder(): about to send new order for size 100 at $151.86 to buy AAPL
# Capital = -3732.0 size = 20700 trade times = 213
# SendTradeOrder(): about to send new order for size 100 at $151.87 to buy AAPL
# Capital = -3527.0 size = 20800 trade times = 214
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -4780.0 size = 20900 trade times = 215
# SendTradeOrder(): about to send new order for size 100 at $151.84 to buy AAPL
# Capital = -4785.0 size = 21000 trade times = 216
# SendTradeOrder(): about to send new order for size 100 at $151.86 to buy AAPL
# Capital = -4159.0 size = 21100 trade times = 217
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3741.0 size = 21200 trade times = 218
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3532.0 size = 21300 trade times = 219
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -3322.9999999995343 size = 21400 trade times = 220
# SendTradeOrder(): about to send new order for size 100 at $151.87 to buy AAPL
# Capital = -3754.0 size = 21500 trade times = 221
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -2680.0000000004657 size = 21600 trade times = 222
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -2681.0000000004657 size = 21700 trade times = 223
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -2682.0000000004657 size = 21800 trade times = 224
# SendTradeOrder(): about to send new order for size 100 at $151.89 to buy AAPL
# Capital = -2901.0 size = 21900 trade times = 225
# SendTradeOrder(): about to send new order for size 100 at $151.89 to buy AAPL
# Capital = -2902.0 size = 22000 trade times = 226
# SendTradeOrder(): about to send new order for size 100 at $151.89 to buy AAPL
# Capital = -2903.0 size = 22100 trade times = 227
# SendTradeOrder(): about to send new order for size 100 at $151.93 to buy AAPL
# Capital = -3351.9999999995343 size = 22200 trade times = 228
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3800.0 size = 22300 trade times = 229
# SendTradeOrder(): about to send new order for size 100 at $151.9 to buy AAPL
# Capital = -3357.9999999995343 size = 22400 trade times = 230
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3810.0 size = 22500 trade times = 231
# SendTradeOrder(): about to send new order for size 100 at $151.88 to buy AAPL
# Capital = -3814.0 size = 22600 trade times = 232
# SendTradeOrder(): about to send new order for size 100 at $151.82 to buy AAPL
# Capital = -5628.0 size = 22700 trade times = 233
# SendTradeOrder(): about to send new order for size 100 at $151.82 to buy AAPL
# Capital = -4950.0 size = 22800 trade times = 234
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5408.999999999534 size = 22900 trade times = 235
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5411.999999999534 size = 23000 trade times = 236
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5414.999999999534 size = 23100 trade times = 237
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5650.0 size = 23200 trade times = 238
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5654.0 size = 23300 trade times = 239
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5658.0 size = 23400 trade times = 240
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5192.0 size = 23500 trade times = 241
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5429.999999999534 size = 23600 trade times = 242
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5432.999999999534 size = 23700 trade times = 243
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5435.999999999534 size = 23800 trade times = 244
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -5438.999999999534 size = 23900 trade times = 245
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -6640.0 size = 24000 trade times = 246
# SendTradeOrder(): about to send new order for size 100 at $151.76 to buy AAPL
# Capital = -6644.0 size = 24100 trade times = 247
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -6646.0 size = 24200 trade times = 248
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -7134.000000000466 size = 24300 trade times = 249
# SendTradeOrder(): about to send new order for size 100 at $151.76 to buy AAPL
# Capital = -6652.0 size = 24400 trade times = 250
# SendTradeOrder(): about to send new order for size 100 at $151.73 to buy AAPL
# Capital = -7143.000000000466 size = 24500 trade times = 251
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -8617.000000000466 size = 24600 trade times = 252
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -8374.0 size = 24700 trade times = 253
# SendTradeOrder(): about to send new order for size 100 at $151.59 to buy AAPL
# Capital = -10600.0 size = 24800 trade times = 254
# SendTradeOrder(): about to send new order for size 100 at $151.62 to buy AAPL
# Capital = -10107.999999999534 size = 24900 trade times = 255
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = -10610.0 size = 25000 trade times = 256
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = -10614.0 size = 25100 trade times = 257
# SendTradeOrder(): about to send new order for size 100 at $151.66 to buy AAPL
# Capital = -9616.0 size = 25200 trade times = 258
# SendTradeOrder(): about to send new order for size 100 at $151.66 to buy AAPL
# Capital = -9622.0 size = 25300 trade times = 259
# SendTradeOrder(): about to send new order for size 100 at $151.66 to buy AAPL
# Capital = -9628.0 size = 25400 trade times = 260
# SendTradeOrder(): about to send new order for size 100 at $151.59 to buy AAPL
# Capital = -10392.0 size = 25500 trade times = 261
# SendTradeOrder(): about to send new order for size 100 at $151.59 to buy AAPL
# Capital = -10394.0 size = 25600 trade times = 262
# SendTradeOrder(): about to send new order for size 100 at $151.66 to buy AAPL
# Capital = -8861.0 size = 25700 trade times = 263
# SendTradeOrder(): about to send new order for size 100 at $151.65 to buy AAPL
# Capital = -8863.0 size = 25800 trade times = 264
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7316.0 size = 25900 trade times = 265
# SendTradeOrder(): about to send new order for size 100 at $151.71 to buy AAPL
# Capital = -7578.0 size = 26000 trade times = 266
# SendTradeOrder(): about to send new order for size 100 at $151.71 to buy AAPL
# Capital = -7059.000000000466 size = 26100 trade times = 267
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5757.0 size = 26200 trade times = 268
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5760.0 size = 26300 trade times = 269
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -8130.0 size = 26400 trade times = 270
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7869.000000000466 size = 26500 trade times = 271
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -8138.0 size = 26600 trade times = 272
# SendTradeOrder(): about to send new order for size 100 at $151.64 to buy AAPL
# Capital = -10271.999999999534 size = 26700 trade times = 273
# SendTradeOrder(): about to send new order for size 100 at $151.64 to buy AAPL
# Capital = -10277.999999999534 size = 26800 trade times = 274
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -8138.0 size = 26900 trade times = 275
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -7601.0 size = 27000 trade times = 276
# SendTradeOrder(): about to send new order for size 100 at $151.69 to buy AAPL
# Capital = -7602.0 size = 27100 trade times = 277
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -8690.000000000466 size = 27200 trade times = 278
# SendTradeOrder(): about to send new order for size 100 at $151.68 to buy AAPL
# Capital = -8694.000000000466 size = 27300 trade times = 279
# SendTradeOrder(): about to send new order for size 100 at $151.66 to buy AAPL
# Capital = -9244.0 size = 27400 trade times = 280
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7602.0 size = 27500 trade times = 281
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7604.0 size = 27600 trade times = 282
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7606.0 size = 27700 trade times = 283
# SendTradeOrder(): about to send new order for size 100 at $151.7 to buy AAPL
# Capital = -7608.0 size = 27800 trade times = 284
# SendTradeOrder(): about to send new order for size 100 at $151.71 to buy AAPL
# Capital = -7053.0 size = 27900 trade times = 285
# SendTradeOrder(): about to send new order for size 100 at $151.72 to buy AAPL
# Capital = -7335.0 size = 28000 trade times = 286
# SendTradeOrder(): about to send new order for size 100 at $151.74 to buy AAPL
# Capital = -6216.0 size = 28100 trade times = 287
# SendTradeOrder(): about to send new order for size 100 at $151.76 to buy AAPL
# Capital = -5937.0 size = 28200 trade times = 288
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5375.0 size = 28300 trade times = 289
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5377.0 size = 28400 trade times = 290
# SendTradeOrder(): about to send new order for size 100 at $151.78 to buy AAPL
# Capital = -5379.0 size = 28500 trade times = 291
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -4525.0 size = 28600 trade times = 292
# SendTradeOrder(): about to send new order for size 100 at $151.79 to buy AAPL
# Capital = -5099.0 size = 28700 trade times = 293
# SendTradeOrder(): about to send new order for size 100 at $151.8 to buy AAPL
# Capital = -4814.0 size = 28800 trade times = 294
# SendTradeOrder(): about to send new order for size 100 at $151.83 to buy AAPL
# Capital = -3663.0 size = 28900 trade times = 295
# SendTradeOrder(): about to send new order for size 100 at $151.82 to buy AAPL
# Capital = -4823.0 size = 29000 trade times = 296
# SendTradeOrder(): about to send new order for size 100 at $151.82 to buy AAPL
# Capital = -4827.0 size = 29100 trade times = 297
# SendTradeOrder(): about to send new order for size 100 at $151.85 to buy AAPL
# Capital = -3374.0 size = 29200 trade times = 298
# ...
# Capital = 42447.0 size = 636200 trade times = 6368
# SendTradeOrder(): about to send new order for size 100 at $151.26 to buy AAPL
# Capital = 42446.0 size = 636300 trade times = 6369
# SendTradeOrder(): about to send new order for size 100 at $151.26 to buy AAPL
# Capital = 42445.0 size = 636400 trade times = 6370
# SendTradeOrder(): about to send new order for size 100 at $151.26 to buy AAPL
# Capital = 42444.0 size = 636500 trade times = 6371
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 36078.0 size = 636600 trade times = 6372
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 29675.0 size = 636700 trade times = 6373
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 23306.0 size = 636800 trade times = 6374
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16936.0 size = 636900 trade times = 6375
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 10565.0 size = 637000 trade times = 6376
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16933.0 size = 637100 trade times = 6377
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16931.0 size = 637200 trade times = 6378
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = -754204.0 size = 637300 trade times = 6379
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 10554.0 size = 637400 trade times = 6380
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16926.0 size = 637500 trade times = 6381
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16924.0 size = 637600 trade times = 6382
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16922.0 size = 637700 trade times = 6383
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 16920.0 size = 637800 trade times = 6384
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 10540.0 size = 637900 trade times = 6385
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 4158.0 size = 638000 trade times = 6386
# SendTradeOrder(): about to send new order for size 100 at $151.2 to buy AAPL
# Capital = 4157.0 size = 638100 trade times = 6387
# SendTradeOrder(): about to send new order for size 100 at $151.2 to buy AAPL
# Capital = -2226.0 size = 638200 trade times = 6388
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -2227.0 size = 638300 trade times = 6389
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -2228.0 size = 638400 trade times = 6390
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -2229.0 size = 638500 trade times = 6391
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -21386.0 size = 638600 trade times = 6392
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -15001.0 size = 638700 trade times = 6393
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -21390.0 size = 638800 trade times = 6394
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -15003.0 size = 638900 trade times = 6395
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -15004.0 size = 639000 trade times = 6396
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -15005.0 size = 639100 trade times = 6397
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -8616.000000014901 size = 639200 trade times = 6398
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -8618.000000014901 size = 639300 trade times = 6399
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -8620.000000014901 size = 639400 trade times = 6400
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -756835.0 size = 639500 trade times = 6401
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -756952.0 size = 639600 trade times = 6402
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -757069.0 size = 639700 trade times = 6403
# SendTradeOrder(): about to send new order for size 100 at $151.17 to buy AAPL
# Capital = -15018.0 size = 639800 trade times = 6404
# SendTradeOrder(): about to send new order for size 100 at $151.18 to buy AAPL
# Capital = -27818.0000000149 size = 639900 trade times = 6405
# SendTradeOrder(): about to send new order for size 100 at $151.2 to buy AAPL
# Capital = -2224.0 size = 640000 trade times = 6406
# SendTradeOrder(): about to send new order for size 100 at $151.2 to buy AAPL
# Capital = -2226.0 size = 640100 trade times = 6407
# SendTradeOrder(): about to send new order for size 100 at $151.2 to buy AAPL
# Capital = -2228.0 size = 640200 trade times = 6408
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -2260.0 size = 640300 trade times = 6409
# SendTradeOrder(): about to send new order for size 100 at $151.21 to buy AAPL
# Capital = -757935.0 size = 640400 trade times = 6410
# SendTradeOrder(): about to send new order for size 100 at $151.23 to buy AAPL
# Capital = 23352.0 size = 640500 trade times = 6411
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 23350.0 size = 640600 trade times = 6412
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 23348.0 size = 640700 trade times = 6413
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = -758430.0 size = 640800 trade times = 6414
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 29753.0 size = 640900 trade times = 6415
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = -758678.0 size = 641000 trade times = 6416
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 29751.0 size = 641100 trade times = 6417
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 29749.0 size = 641200 trade times = 6418
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 29747.0 size = 641300 trade times = 6419
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 16920.0 size = 641400 trade times = 6420
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 16919.0 size = 641500 trade times = 6421
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 16918.0 size = 641600 trade times = 6422
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 16917.0 size = 641700 trade times = 6423
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -2335.0 size = 641800 trade times = 6424
# SendTradeOrder(): about to send new order for size 100 at $151.19 to buy AAPL
# Capital = -2336.0 size = 641900 trade times = 6425
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 16892.0 size = 642000 trade times = 6426
# SendTradeOrder(): about to send new order for size 100 at $151.2 to buy AAPL
# Capital = -2370.0 size = 642100 trade times = 6427
# SendTradeOrder(): about to send new order for size 100 at $151.21 to buy AAPL
# Capital = 10471.0 size = 642200 trade times = 6428
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -760319.0 size = 642300 trade times = 6429
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -760469.0 size = 642400 trade times = 6430
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -21744.0 size = 642500 trade times = 6431
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -15353.0 size = 642600 trade times = 6432
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -21814.0 size = 642700 trade times = 6433
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 29575.0 size = 642800 trade times = 6434
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 29574.0 size = 642900 trade times = 6435
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 23142.0 size = 643000 trade times = 6436
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -761468.0 size = 643100 trade times = 6437
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 48814.0 size = 643200 trade times = 6438
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 42357.0 size = 643300 trade times = 6439
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 35898.0 size = 643400 trade times = 6440
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -762068.0 size = 643500 trade times = 6441
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -762218.0 size = 643600 trade times = 6442
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -762368.0 size = 643700 trade times = 6443
# SendTradeOrder(): about to send new order for size 100 at $151.28 to buy AAPL
# Capital = 29378.0 size = 643800 trade times = 6444
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 29351.0 size = 643900 trade times = 6445
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 22910.0 size = 644000 trade times = 6446
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 22908.0 size = 644100 trade times = 6447
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 22906.0 size = 644200 trade times = 6448
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 22904.0 size = 644300 trade times = 6449
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 22902.0 size = 644400 trade times = 6450
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 29319.0 size = 644500 trade times = 6451
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = -763541.0 size = 644600 trade times = 6452
# SendTradeOrder(): about to send new order for size 100 at $151.26 to buy AAPL
# Capital = 35761.0 size = 644700 trade times = 6453
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 42183.0 size = 644800 trade times = 6454
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 42158.0 size = 644900 trade times = 6455
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 42133.0 size = 645000 trade times = 6456
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = 42108.0 size = 645100 trade times = 6457
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 29205.0 size = 645200 trade times = 6458
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 29204.0 size = 645300 trade times = 6459
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -764665.0 size = 645400 trade times = 6460
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -764815.0 size = 645500 trade times = 6461
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -764965.0 size = 645600 trade times = 6462
# SendTradeOrder(): about to send new order for size 100 at $151.5 to buy AAPL
# Capital = -765115.0 size = 645700 trade times = 6463
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = 29095.0 size = 645800 trade times = 6464
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 35552.0 size = 645900 trade times = 6465
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 35551.0 size = 646000 trade times = 6466
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 35550.0 size = 646100 trade times = 6467
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = -765738.0 size = 646200 trade times = 6468
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = -765862.0 size = 646300 trade times = 6469
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 35549.0 size = 646400 trade times = 6470
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = -766111.0 size = 646500 trade times = 6471
# SendTradeOrder(): about to send new order for size 100 at $151.24 to buy AAPL
# Capital = -766235.0 size = 646600 trade times = 6472
# SendTradeOrder(): about to send new order for size 100 at $151.22 to buy AAPL
# Capital = 16150.0 size = 646700 trade times = 6473
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 16111.0 size = 646800 trade times = 6474
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 41948.0 size = 646900 trade times = 6475
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 41913.0 size = 647000 trade times = 6476
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 41878.0 size = 647100 trade times = 6477
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 28899.0 size = 647200 trade times = 6478
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 28897.0 size = 647300 trade times = 6479
# SendTradeOrder(): about to send new order for size 100 at $151.25 to buy AAPL
# Capital = 28895.0 size = 647400 trade times = 6480
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 41808.0 size = 647500 trade times = 6481
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 48249.0 size = 647600 trade times = 6482
# SendTradeOrder(): about to send new order for size 100 at $151.6 to buy AAPL
# Capital = 48215.0 size = 647700 trade times = 6483
# SendTradeOrder(): about to send new order for size 100 at $152.6 to buy AAPL
# Capital = 48081.0 size = 647800 trade times = 6484
#
#
# Text Backtest experiment 1 completed in 7.99723 secsand processed 301682 ticks for a throughput of 37723.3 ticks per second
# Backtest experiment 1 finished.
# run_backtest.sh: Strategy Studio finished backtesting
# CRA file found:, /home/vagrant/ss/bt/backtesting-results/BACK_TestPybindStrategy_2023-09-18_182146_start_11-05-2021_end_11-05-2021.cra
# Login received from connection id 1
#
# export successful
#
# Quitting.
# Connection id 1 finished.
# Connection id 1 finished.
# Caught a signal: 1. Alerting Strategy Studio...
# Stopping Strategy Studio Backtesting Server...
# Stopping Strategy Server...
# Application state changed to STATE_APP_STOPPING
# vagrant-scp plugin is installed.
# Warning: Permanently added '[127.0.0.1]:2222' (ED25519) to the list of known hosts.
# BACK_TestPybindStrategy_2023-09-18_182146_sta 100%   24KB   7.9MB/s   00:00
# BACK_TestPybindStrategy_2023-09-18_182146_sta 100% 1189KB  30.3MB/s   00:00

# %% [markdown]
# # Do All data viz in the cell below

# %%
# Do data viz here
from position import plotPositions
from graphPNL import graphPNL

plotPositions()
graphPNL()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Do data viz here
# ----> 2 from position import plotPositions
#       3 from graphPNL import graphPNL
#       5 plotPositions()
#
# File ~/Documents/IE421/group_02_project/PybindStrategy/VisualizationScript/position.py:1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.dates as mdates
#
# ModuleNotFoundError: No module named 'pandas'
